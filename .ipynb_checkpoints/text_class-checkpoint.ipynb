# %%
import json
import pandas as pd
import json

# %%
json_file=r"C:\Users\Lora\Desktop\TxMM\Project\news-category-dataset\News_Category_Dataset_v2.json"

## investigate data 
data = []
for line in open(json_file,'r'):
    data.append(json.loads(line))
    
# Creates DataFrame. 
df_headline = pd.DataFrame(data) 
df_short_desc = pd.DataFrame(data)

# Dropping unnecessary categories from both data frames
df_headline = df_headline.drop(['date','authors','link','short_description'], axis=1)
df_short_desc = df_short_desc.drop(['date','authors','link','headline'], axis=1)

# Grouping similar categories in data frame for headline 
df_headline.loc[df_headline['category'] == 'COLLEGE', 'category'] = 'EDUCATION'
df_headline.loc[df_headline['category'] == 'CULTURE & ARTS', 'category'] = 'ARTS'
df_headline.loc[df_headline['category'] == 'ARTS & CULTURE', 'category'] = 'ARTS'
df_headline.loc[df_headline['category'] == 'THE WORLDPOST', 'category'] = 'WORLDPOST'
df_headline.loc[df_headline['category'] == 'WORLD NEWS', 'category'] = 'WORLDPOST'
df_headline.loc[df_headline['category'] == 'GREEN', 'category'] = 'ENVIRONMENT'
df_headline.loc[df_headline['category'] == 'PARENTING', 'category'] = 'PARENTS'
df_headline.loc[df_headline['category'] == 'STYLE & BEAUTY', 'category'] = 'STYLE'

# Dropping categories with two little samples for headline 
df_headline=df_headline.drop(df_headline[df_headline.category == 'FIFTY'].index)
df_headline=df_headline.drop(df_headline[df_headline.category == 'GOOD NEWS'].index)
df_headline=df_headline.drop(df_headline[df_headline.category == 'LATINO VOICES'].index)
df_headline=df_headline.drop(df_headline[df_headline.category == 'MONEY'].index)
df_headline=df_headline.drop(df_headline[df_headline.category == 'WEIRD NEWS'].index)
df_headline=df_headline.drop(df_headline[df_headline.category == 'TASTE'].index)
df_headline=df_headline.drop(df_headline[df_headline.category == 'TECH'].index)

# Grouping similar categories in data frame for short desc 
df_short_desc.loc[df_short_desc['category'] == 'COLLEGE', 'category'] = 'EDUCATION'
df_short_desc.loc[df_short_desc['category'] == 'CULTURE & ARTS', 'category'] = 'ARTS'
df_short_desc.loc[df_short_desc['category'] == 'ARTS & CULTURE', 'category'] = 'ARTS'
df_short_desc.loc[df_short_desc['category'] == 'THE WORLDPOST', 'category'] = 'WORLDPOST'
df_short_desc.loc[df_short_desc['category'] == 'WORLD NEWS', 'category'] = 'WORLDPOST'
df_short_desc.loc[df_short_desc['category'] == 'GREEN', 'category'] = 'ENVIRONMENT'
df_short_desc.loc[df_short_desc['category'] == 'PARENTING', 'category'] = 'PARENTS'
df_short_desc.loc[df_short_desc['category'] == 'STYLE & BEAUTY', 'category'] = 'STYLE'

# Dropping categories with two little samples for short desc  
df_short_desc=df_short_desc.drop(df_short_desc[df_short_desc.category == 'FIFTY'].index)
df_short_desc=df_short_desc.drop(df_short_desc[df_short_desc.category == 'GOOD NEWS'].index)
df_short_desc=df_short_desc.drop(df_short_desc[df_short_desc.category == 'LATINO VOICES'].index)
df_short_desc=df_short_desc.drop(df_short_desc[df_short_desc.category == 'MONEY'].index)
df_short_desc=df_short_desc.drop(df_short_desc[df_short_desc.category == 'WEIRD NEWS'].index)
df_short_desc=df_short_desc.drop(df_short_desc[df_short_desc.category == 'TASTE'].index)
df_short_desc=df_short_desc.drop(df_short_desc[df_short_desc.category == 'TECH'].index)

# reseting index for both tables
df_headline=df_headline.reset_index(drop=True)
df_short_desc=df_short_desc.reset_index(drop=True)

# checking categories
df_headline.groupby('category').count()
df_short_desc.groupby('category').count()

# categories 
h = ["ARTS","BLACK VOICES","BUSINESS","COMEDY","CRIME","DIVORCE","EDUCATION","ENTERTAINMENT","ENVIRONMENT",
             "FOOD & DRINK","HEALTHY LIVING","HOME & LIVING","IMPACT","MEDIA","PARENTS","POLITICS","QUEER VOICES",
             "RELIGION","SCIENCE","SPORTS","STYLE","TRAVEL","WEDDINGS","WELLNESS","WOMEN","WORLDPOST"]
sd = ["ARTS","BLACK VOICES","BUSINESS","COMEDY","CRIME","DIVORCE","EDUCATION","ENTERTAINMENT","ENVIRONMENT",
             "FOOD & DRINK","HEALTHY LIVING","HOME & LIVING","IMPACT","MEDIA","PARENTS","POLITICS","QUEER VOICES",
             "RELIGION","SCIENCE","SPORTS","STYLE","TRAVEL","WEDDINGS","WELLNESS","WOMEN","WORLDPOST"]

# %%
## plotting - same graph is for the headline and for short_desc
## initial 
import matplotlib.pyplot as plt
counts = df_headline.groupby('category').count()
counts = counts.rename(columns={"category": "category", "headline": "frequency"})
counts.plot(kind='bar')

# %%
# now checking for average lenght of headlines, and short descriptions, and variance
# if variance is to big then will ignore short/too long samples to reduce variance 
import pylab as pl
# get number of words per headline
df_headline['Numb of words'] = df_headline['headline'].str.count(' ')
average_length_head = df_headline.loc[:,"Numb of words"].mean()
st_dev_head = df_headline.loc[:,"Numb of words"].std()

# plotting average number of words per category in headlines
df_numb_of_word = df_headline.drop(columns="headline")
df_numb_of_word= df_numb_of_word.groupby('category').mean()
df_numb_of_word = df_numb_of_word.rename(columns={"category": "category", "Numb of words": "Average number of words"})
df_numb_of_word.plot(kind='bar')
pl.suptitle("Average number of words per category for headlines")
# Out:
# Text(0.5, 0.98, 'Average number of words per category for headlines')

# %%
# get number of words per short description
df_short_desc['Numb of words'] = df_short_desc['short_description'].str.count(' ')
average_length_shd = df_short_desc.loc[:,"Numb of words"].mean()
st_dev_shd = df_short_desc.loc[:,"Numb of words"].std()

# plotting average number of words per category in headlines
df_numb_of_word_sh = df_short_desc.drop(columns="short_description")
df_numb_of_word_sh= df_numb_of_word_sh.groupby('category').mean()
df_numb_of_word_sh = df_numb_of_word_sh.rename(columns={"category": "category", "Numb of words": "Average number of words"})
df_numb_of_word_sh.plot(kind='bar')
pl.suptitle("Average number of words per category for short description")
# Out:
# Text(0.5, 0.98, 'Average number of words per category for short description')

# %%
# splitting data set into train/test
from sklearn.model_selection import train_test_split
import numpy as np

# dropping columns we don't need more 
#train_h = train_h.drop(columns=['Numb of words'])
#test_h =test_h.drop(columns=['Numb of words'])
#train_sh_d = train_sh_d.drop(columns=['Numb of words'])
#test_sh_d = test_sh_d.drop(columns=['Numb of words'])

# removing empty rows from training/test set for short descriptions
#train_sh_d['short_description'].replace('', np.nan, inplace=True)
#train_sh_d.dropna(subset=['short_description'], inplace=True)
#test_sh_d['short_description'].replace('', np.nan, inplace=True)
#test_sh_d.dropna(subset=['short_description'], inplace=True)


# --> for the case of headlines, there are no empty rows

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize, sent_tokenize
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
## !!!!!! pokusaj 
# take smaler example just to try stufff
aa = df_headline['headline'].head(2000)
bb = df_headline['category'].head(2000)
# rastavi na train/test
#train_x, valid_x,train_y, valid_y = model_selection.train_test_split(df_headline['headline'], df_headline['category'],test_size=0.20)
train_x, valid_x,train_y, valid_y = model_selection.train_test_split(aa,bb,test_size=0.20)

# %%
# Out:
# 400

# %%
stop_words = set(stopwords.words('english'))
import string
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

import re 
# removing numbers from string   
def remove(tt): 
    pattern = '[0-9]'
    a = re.sub(pattern, '',tt) 
    return a

def remove_stopwords(text):
    help_list=[]
    stop_words = set(stopwords.words('english'))
    for item in text.split(' '):
        if item not in stop_words:
            help_list.append(item)
    a = ' '.join(help_list)
    return a
#trasnform into df
train_x_df = pd.DataFrame(train_x)
#make new column with lower case
train_x_df['no_caps'] = train_x_df['headline'].str.lower()
# removing punct 
train_x_df['no_pun'] = train_x_df['no_caps'].apply(remove_punctuations)
# removing numbers
train_x_df['no_pun'] = train_x_df['no_pun'].apply(remove)
# removing stop words 
train_x_df['no_pun'] = train_x_df['no_pun'].apply(remove_stopwords)





#tokenize each word
#train_x_df['tokenized'] = train_x_df['no_pun'].apply(nltk.word_tokenize)
#removing stop words

#train_x_df['cleaning']=train_x_df['tokenized'].apply(lambda x: [item for item in x if item not in stop_words])
# removing numbers 
#train_x_df['cleaning'] = train_x_df['cleaning'].apply(remove)
#removing empty strings 
#train_x_df['clean']=train_x_df['cleaning'].apply(lambda x: [item for item in x if item != '']) 
#

## numbers and punct 
#bbb = [x.translate(str.maketrans('', '', string.punctuation + string.digits)) for x in bbb ]

# %%
train_x_df.drop(columns=['no_caps'])
# Out:
#                                                headline  \
# 1496  Priyanka Chopra Reveals Big Spoilers For Seaso...
# 84    This Women Pulled Out All The Stops To Land He...
# 952                 Ryan Zinke And The Tale Of Two Fish
# 1270  Kanye West Explains The 'Most Inspiring Thing'...
# 999   Connecticut To Give Its Electoral College Vote...
# 1400  NASA Terminates Last Moon Rover After Trump To...
# 752   3 Americans Held By North Korea Return To The ...
# 1159  GOP Candidate Connects Boy Scouts Name Change ...
# 1425  Bill Maher Confronts 'Dear Friend' Roseanne Ba...
# 705   Jimmy Kimmel Roasts Donald Trump With Spoof No...
# 621   Michael Avenatti Posts Photos Of Cohen With Qa...
# 1707  Los Angeles vs. San Francisco: Which City Rule...
# 686   82 Women Take To Cannes Red Carpet To Protest ...
# 944   WHOOPS! Mark Hamill Just Spilled The Beans On ...
# 1735  Channing Tatum And Arie Luyendyk Jr. Have A Da...
# 322   Tina Fey Tries Out For 'Mean Girls' The Musica...
# 1993  FALSE ALARM: No New Missile Attack On Syrian A...
# 389   Steven Tyler Admits To Hitting On Daughter Liv...
# 45    George Takei Accuser Walks Back Story Of Drugg...
# 1237  Some Prosecutors Are Erasing Old Weed Convicti...
# 17    Ireland Votes To Repeal Abortion Amendment In ...
# 303   Belgian Transgender Ballet Drama Wins Big At C...
# 130   Gay Man Denied Marriage License By Kim Davis L...
# 112   Alabama Sues To Exclude Undocumented Immigrant...
# 1775  NYT Reporter Hits Back At Trump, Says She Know...
# 852   How The Refugee Caravan Became A Scapegoat For...
# 1135  FEMA's Latest Excuse For Why It's Ignoring Cli...
# 1912  Former NYC Mayor Rudy Giuliani Is Joining Trum...
# 1263  Scooters, Resisted Elsewhere, Face Less Skepti...
# 283   Democrats Plan Big Anti-Corruption Theme For M...
# ...                                                 ...
# 1742  McKayla Maroney Says She Told Olympic Coach Of...
# 1509  GOP Food Stamp Bill Might Be Harsh Enough Win ...
# 435   Jimmy Kimmel Comes Clean: 'I May Owe Donald Tr...
# 710   John McCain's Wife Rebukes White House Officia...
# 47    Pete Davidson Says His Mental Illness Doesn't ...
# 358   Colbert Has A Super Graphic Way Of Describing ...
# 179   Democrats Weren't Invited To Review Classified...
# 1281  Tracy Morgan Says He Was A 'Crack Dealer With ...
# 354   Santa Fe High Schoolers Held Gun Violence Prot...
# 866   Pinata Maker Apologizes For Hanging Black Figu...
# 851   NY Governor Assigns Investigation Into Eric Sc...
# 817   Europeans Scramble To Save Iran Deal After Tru...
# 989   Catie Turner Forgets Words To 'Manic Monday' O...
# 1858  The Great Barrier Reef Has Been Forever Change...
# 1258  School Hangs Up 'Modesty Ponchos' To Ensure St...
# 1719  Beyoncé Inspired Google To Give $100,000 More ...
# 1250  Kanye West Talks About Getting Liposuction And...
# 1385   Marvel Lied To Us About 'Avengers: Infinity War'
# 1355  Trump Calls For The White House Correspondents...
# 1186  You Can't Unsee Jim Carrey's Naked Trump 'Urin...
# 890   Netanyahu's Chef Blasted For Serving Japan's P...
# 1648  Saudi Coalition Air Strikes Kill At Least 20 A...
# 399   A Comprehensive List Of Everything Don Jr. Doe...
# 1115  A Long Island Record Shop Selling Neo-Nazi Mer...
# 896   Joe Scarborough: Trump's Legal Strategy Is Lik...
# 194   Disney Reveals Opening Seasons For 'Star Wars'...
# 526   Rex Tillerson Warns Grads Of Living In ‘Altern...
# 1492  Anderson Cooper Shreds 'Incoherent' Trump: 'Li...
# 461   Whistleblower Leaked Michael Cohen's Financial...
# 713   Police Search Suspected Serial Killer's Dumpin...
#
#                                                  no_pun
# 1496  priyanka chopra reveals big spoilers season  q...
# 84                    women pulled stops land dream job
# 952                            ryan zinke tale two fish
# 1270  kanye west explains inspiring thing donald tru...
# 999   connecticut give electoral college votes natio...
# 1400  nasa terminates last moon rover trump touts ne...
# 752     americans held north korea return united states
# 1159  gop candidate connects boy scouts name change ...
# 1425  bill maher confronts dear friend roseanne barr...
# 705   jimmy kimmel roasts donald trump spoof nobel p...
# 621   michael avenatti posts photos cohen qatari inv...
# 1707  los angeles vs san francisco city rules west c...
# 686    women take cannes red carpet protest inequali...
# 944   whoops mark hamill spilled beans major cameo h...
# 1735          channing tatum arie luyendyk jr day races
# 322               tina fey tries mean girls musical snl
# 1993  false alarm new missile attack syrian air defe...
# 389   steven tyler admits hitting daughter livs famo...
# 45    george takei accuser walks back story drugging...
# 1237      prosecutors erasing old weed convictions isnt
# 17    ireland votes repeal abortion amendment landsl...
# 303   belgian transgender ballet drama wins big cann...
# 130   gay man denied marriage license kim davis lose...
# 112   alabama sues exclude undocumented immigrants c...
# 1775  nyt reporter hits back trump says knows drunkd...
# 852   refugee caravan became scapegoat trump’s borde...
# 1135  femas latest excuse ignoring climate change fo...
# 1912  former nyc mayor rudy giuliani joining trumps ...
# 1263  scooters resisted elsewhere face less skeptici...
# 283    democrats plan big anticorruption theme midterms
# ...                                                 ...
# 1742  mckayla maroney says told olympic coach nassar...
# 1509  gop food stamp bill might harsh enough win har...
# 435   jimmy kimmel comes clean may owe donald trump ...
# 710   john mccains wife rebukes white house official...
# 47    pete davidson says mental illness doesnt ruin ...
# 358   colbert super graphic way describing deep muel...
# 179   democrats werent invited review classified doc...
# 1281          tracy morgan says crack dealer heart gold
# 354   santa fe high schoolers held gun violence prot...
# 866   pinata maker apologizes hanging black figures ...
# 851   ny governor assigns investigation eric schneid...
# 817   europeans scramble save iran deal trump withdraws
# 989   catie turner forgets words manic monday americ...
# 1858  great barrier reef forever changed global warm...
# 1258  school hangs modesty ponchos ensure students a...
# 1719    beyoncé inspired google give  hbcu scholarships
# 1250  kanye west talks getting liposuction battling ...
# 1385               marvel lied us avengers infinity war
# 1355  trump calls white house correspondents dinner ...
# 1186  cant unsee jim carreys naked trump urine sampl...
# 890   netanyahus chef blasted serving japans prime m...
# 1648  saudi coalition air strikes kill least  yemen ...
# 399   comprehensive list everything jr doesnt know i...
# 1115  long island record shop selling neonazi merch ...
# 896   joe scarborough trumps legal strategy like mon...
# 194   disney reveals opening seasons star wars theme...
# 526   rex tillerson warns grads living ‘alternative ...
# 1492  anderson cooper shreds incoherent trump like c...
# 461   whistleblower leaked michael cohens financials...
# 713   police search suspected serial killers dumping...
#
# [1600 rows x 2 columns]

# %%
# building vocabulary for headline 
from nltk.tokenize import sent_tokenize, word_tokenize 
bow = []
headlines = train_h['headline']
for h in headlines:
    bow.extend(word_tokenize(h))

# %%
#      1. 
# data set prep
# split the dataset into training and validation datasets 
#train_x, valid_x, train_y, valid_y = model_selection.train_test_split(train_h['headline'],train['category'])

# label encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_x_df['no_pun'])
valid_y = encoder.fit_transform(valid_y)

# %%
#     2
# ngram level tf-idf 
def dummy_fun(doc):
    return doc

#tfidf_vect_ngram = TfidfVectorizer(analyzer='word',tokenizer=dummy_fun,preprocessor=dummy_fun, ngram_range=(2,3),token_pattern=None).fit(train_x)
tfidf_vect_ngram = TfidfVectorizer(analyzer='word', ngram_range=(2,3),token_pattern=r'\w{1,}',max_features=5000)
xtrain_tfidf_ngram =  tfidf_vect_ngram.fit_transform(train_x_df['no_pun'])
xvalid_tfidf_ngram =  tfidf_vect_ngram.transform(valid_x)

# %%
#    2.a
# this is for average word, but we should use sentence 
trainDF['char_count'] = trainDF['text'].apply(len)
trainDF['word_count'] = trainDF['text'].apply(lambda x: len(x.split()))
trainDF['word_density'] = trainDF['char_count'] / (trainDF['word_count']+1)

# %%
#    2.b (maybe)
from sklearn import decomposition, ensemble
# train a LDA Model
# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', tokenizer=dummy_fun,preprocessor=dummy_fun,token_pattern=None)
count_vect.fit(train_x_df['clean'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)
xvalid_count =  count_vect.transform(valid_x)
lda_model = decomposition.LatentDirichletAllocation(n_components=20, learning_method='online', max_iter=20)
X_topics = lda_model.fit_transform(xtrain_count)
topic_word = lda_model.components_ 
vocab = count_vect.get_feature_names()


import numpy
# view the topic models
n_top_words = 10
topic_summaries = []
for i, topic_dist in enumerate(topic_word):
    topic_words = numpy.array(vocab)[numpy.argsort(topic_dist)][:-(n_top_words+1):-1]
    topic_summaries.append(' '.join(topic_words))

# %%
# utility function for training 
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)

    
    return metrics.recall_score(predictions, valid_y,average='macro')

# %%
from sklearn.preprocessing import StandardScaler
def classify_SVM(train_features, train_labels, test_features):
    sc = StandardScaler()
    #X_train_std=sc.fit_transform(train_features)
    #X_validation_std=sc.transform(test_features)
    
    clf = svm.SVC(kernel='linear')
    clf.fit(train_features, train_labels)
    return clf.predict(test_features)

# training linear SVM with tf idf after cleaning text 
y_pred = classify_SVM(xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
y_pred
import sklearn
scores=[]
scores.append(evaluate(valid_y, y_pred))
recall = sum([x[0] for x in scores]) / len(scores)
print("Averaged total recall", recall)
precision = sum([x[1] for x in scores]) / len(scores)
print("Averaged total precision", precision)
# results from training model 
#Recall: 0.160581
#Precision: 0.411511
#F1-score: 0.179653
#Averaged total recall 0.1605806960210985
#Averaged total precision 0.41151066455138374
# Out:
# Recall: 0.000000
# Precision: 0.000000
# F1-score: 0.000000
# Averaged total recall 0.0
# Averaged total precision 0.0

# %%
y_pred = classify_SVM(xtrain_tfidf_ngram, train_data.target, test_features)
evaluate(test_data.target, y_pred)

# %%
from sklearn.naive_bayes import MultinomialNB
def classify_NaiveBayes(train_features, train_labels, test_features):
    clfrNB = MultinomialNB(alpha=0.1)
    clfrNB.fit(train_features,train_labels)
    pred = clfrNB.predict(test_features)   
    return pred

#training NB with n gram tf idf after cleaning 
y_pred_NB=classify_NaiveBayes(xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
scores=[]
scores.append(evaluate(valid_y, y_pred))
recall = sum([x[0] for x in scores]) / len(scores)
print("Averaged total recall", recall)
precision = sum([x[1] for x in scores]) / len(scores)
print("Averaged total precision", precision)

#results
#Recall: 0.160581
#Precision: 0.411511
#F1-score: 0.179653
#Averaged total recall 0.1605806960210985
#Averaged total precision 0.41151066455138374
# Out:
# Recall: 0.160581
# Precision: 0.411511
# F1-score: 0.179653
# Averaged total recall 0.1605806960210985
# Averaged total precision 0.41151066455138374
# C:\Users\Lora\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Lora\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.linear_model import LogisticRegression
def classify_LogRegression(train_features, train_labels, test_features):
    clf = LogisticRegression(random_state=0).fit(train_features, train_labels)
    return clf.predict(test_features)

#training LG with n gram tf idf after cleaning 
y_pred_LR=classify_LogRegression(xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
scores=[]
scores.append(evaluate(valid_y, y_pred))
recall = sum([x[0] for x in scores]) / len(scores)
print("Averaged total recall", recall)
precision = sum([x[1] for x in scores]) / len(scores)
print("Averaged total precision", precision)

#results - without scaling targets
#Recall: 0.160581
#Precision: 0.411511
#F1-score: 0.179653
#Averaged total recall 0.1605806960210985
#Averaged total precision 0.41151066455138374
# Out:
# Recall: 0.160581
# Precision: 0.411511
# F1-score: 0.179653
# Averaged total recall 0.1605806960210985
# Averaged total precision 0.41151066455138374
# C:\Users\Lora\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Lora\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\Lora\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Lora\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
def evaluate(y_true, y_pred):
    # TODO: What is being evaluated here and what does it say about the performance? Include or change the evaluation
    # TODO: if necessary.
    recall = sklearn.metrics.recall_score(y_true, y_pred, average='macro')
    print("Recall: %f" % recall)

    precision = sklearn.metrics.precision_score(y_true, y_pred, average='macro')
    print("Precision: %f" % precision)

    f1_score = sklearn.metrics.f1_score(y_true, y_pred, average='macro')
    print("F1-score: %f" % f1_score)

    return recall, precision, f1_score
